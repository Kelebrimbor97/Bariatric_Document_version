# %%
import chromadb
from chromadb.config import Settings

# %%
client = chromadb.PersistentClient(
    path="/home/nishad/Bariatric/Data/chroma_dbs/chroma_notes_biomedclip",
    settings=Settings(anonymized_telemetry=False),
)

# %%
collection = client.get_collection("notes_chunks")

# %%
print(collection.count())
# Out:
# 178901

# %%
collection.peek(1)["metadatas"][0]
# Out:
# {'chunk_id': 0,
#  'record_id': '385f45a7a4d2de68a002383c73d69fe9703a419ee008cde3ee65310912fdbbb2'}
